# %% [markdown]
# <a href="https://colab.research.google.com/github/kowshik20/ML_Learning/blob/main/Hyperparameter_Tuning_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Tasks to Perform** (Hyperparameter Tuning - based Approach)
#
# - **Understand the Problem and Setup**: Define objectives, install/import required libraries, and configure the environment for an Hyperparameter Tuning -  prediction task.
# - **Load and Inspect Data**: Import the dataset, examine its structure, and analyze the columns and data types.
# - **Clean the Data**: Handle missing, duplicate, or inconsistent values, and ensure data types are accurate.
# - **Conduct Exploratory Data Analysis (EDA)**: Use statistical summaries and visualizations (e.g., histograms, heatmaps) to identify patterns and relationships.
# - **Split Data and Preprocess**: Divide the dataset into training and testing sets, and preprocess the data for Hyperparameter Tuning.
# - **Train Hyperparameter Tuning Model**: Implement and train an Hyperparameter Tuning to predict Result.
# - **Report and Document**: Record observations, insights, and key findings throughout the process.
#
# ---
#
# ### **NOTE**
# - Adapt the steps based on the specific problem statement, requirements, and data.
# - Focus on solving the problem efficiently by prioritizing relevant tasks.

# %% [markdown]
# # Problem Statement:
#
# Develop a machine learning model to predict the academic outcome of students (dropout, enrolled, or graduate) based on their enrollment data, including academic history, demographics, socio-economic factors, and first-year performance. This will enable early identification of students at risk of dropout to implement timely intervention strategies.
#
# ---
#
# **Note:**
# - 1 – yes 0 – no
# - 1 – male 0 – female
#
# ### Column Description:
# 1. **Marital status**: The marital status of the student (e.g., single, married).
# 2. **Application mode**: The mode of application used by the student (e.g., online, in-person).
# 3. **Application order**: The order in which the application was submitted.
# 4. **Course**: The course or program the student is enrolled in.
# 5. **Daytime/evening attendance**: Whether the student attends classes during the day or evening.
# 6. **Previous qualification**: The qualification the student had before enrolling in the current course.
# 7. **Previous qualification (grade)**: The grade or score of the student's previous qualification.
# 8. **Nacionality**: The nationality of the student.
# 9. **Mother's qualification**: The educational qualification of the student's mother.
# 10. **Father's qualification**: The educational qualification of the student's father.
# 11. **Mother's occupation**: The occupation of the student's mother.
# 12. **Father's occupation**: The occupation of the student's father.
# 13. **Admission grade**: The grade the student achieved during the admission process.
# 14. **Displaced**: Indicates whether the student is displaced (e.g., living away from home).
# 15. **Educational special needs**: Whether the student has any special educational needs.
# 16. **Debtor**: Indicates whether the student has outstanding debts (e.g., tuition fees).
# 17. **Tuition fees up to date**: Whether the student's tuition fees are fully paid.
# 18. **Gender**: The gender of the student (e.g., male, female, non-binary).
# 19. **Scholarship holder**: Indicates whether the student is a scholarship recipient.
# 20. **Age at enrollment**: The age of the student at the time of enrollment.
# 21. **International**: Whether the student is an international student.
# 22. **Curricular units 1st sem (credited)**: The number of curricular units credited in the first semester.
# 23. **Curricular units 1st sem (enrolled)**: The number of curricular units the student enrolled in during the first semester.
# 24. **Curricular units 1st sem (evaluations)**: The number of evaluations completed in the first semester.
# 25. **Curricular units 1st sem (approved)**: The number of curricular units the student passed in the first semester.
# 26. **Curricular units 1st sem (grade)**: The grades achieved in the first semester.
# 27. **Curricular units 1st sem (without evaluations)**: The number of curricular units without evaluations in the first semester.
# 28. **Curricular units 2nd sem (credited)**: The number of curricular units credited in the second semester.
# 29. **Curricular units 2nd sem (enrolled)**: The number of curricular units the student enrolled in during the second semester.
# 30. **Curricular units 2nd sem (evaluations)**: The number of evaluations completed in the second semester.
# 31. **Curricular units 2nd sem (approved)**: The number of curricular units the student passed in the second semester.
# 32. **Curricular units 2nd sem (grade)**: The grades achieved in the second semester.
# 33. **Curricular units 2nd sem (without evaluations)**: The number of curricular units without evaluations in the second semester.
# 34. **Unemployment rate**: The unemployment rate in the region during the student's studies.
# 35. **Inflation rate**: The inflation rate in the region during the student's studies.
# 36. **GDP**: The Gross Domestic Product of the region during the student's studies.
# 37. **Target**: The final status of the student at the end of the normal course duration (e.g., dropout, enrolled, graduate).

# %% [markdown]
# ---
#
# ## Completion Criteria
# Your submission will be considered valid if:
# - You train and evaluate the Hyperparameter Tuning model and generate predictions for the test dataset.
#
#
# ---
#
#
# ## Output Format
# The final output should be a dataframe of predictions on the `test_data` (provided to you).
#
# It should consist of two columns:
# - **id**: Identifier from the test data.
# - **Target**: Predicted the Target.
#
# ### Sample Output:
# |   id   |   income   |
# |--------|------------|
# |   3    |     0      |
# |   5    |     2      |
# |   8    |     0      |
# |   13   |     0      |
# |   20   |     2      |

# %% [markdown]
# ## Import Required Libraries

# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV, cross_val_score, StratifiedKFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Load Data
# - Do not modify the given code. Execute the below code cells sequencially so get the data.

# %%
train_data = pd.read_csv('https://new-assets.ccbp.in/frontend/content/aiml/classical-ml/student_dataset.csv')
test_data = pd.read_csv('https://new-assets.ccbp.in/frontend/content/aiml/classical-ml/student_dataset_test.csv')

# %%
train_data.head()

# %%
test_data.head()

# %% [markdown]
# ## Implementation
# - Write the code in the below code cell. Create new code cells if required.
# - Build the Decision Tree model on the provided `train_data` import and use the appropriate libraries required for building the model.
# - Evaluate the model on `test_data` and get the predictions
# - Submit the predictions in `.csv` format. Read submission guidlines carefully.

# %%
# ADD YOUR CODE HERE

# %% [markdown]
# ## Predict on Test data

# %%
# Predict on the test data

# %% [markdown]
# ## Your Final Submission
# ### Instructions
#
# - **Write Your Solution in the Provided Code Cell**
#    - Use the code cell provided below for your final solution.
#    - **Do not delete** this code cell or create a new one.
#
# - **Avoid Creating New Cells**
#    - If you delete the provided code cell and create a new one to write your code, it will not be evaluated.
#    - In such cases, you will need to create a new copy of the notebook from the platform and re-write your code.
#
# - **Follow a Step-by-Step Approach**
#    - Merge your solution step-by-step in the provided code cell:
#      - Start by importing the required libraries.
#      - Load the data.
#      - Perform data pre-processing.
#      - Split the data into training and testing sets.
#      - Build the model.
#      - Evaluate the model performance.
#    - Ensure the steps are followed in a proper sequence for clarity and correctness.

# %%
# Initialize the GridSearchCV


# Fit the GridSearchCV to the training data

# %%
# Write your code here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV, cross_val_score, StratifiedKFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix

import warnings
warnings.filterwarnings("ignore")

train_data = pd.read_csv('https://new-assets.ccbp.in/frontend/content/aiml/classical-ml/student_dataset.csv')
test_data = pd.read_csv('https://new-assets.ccbp.in/frontend/content/aiml/classical-ml/student_dataset_test.csv')

# 2. Clean and Prepare Data (from cell b7d21b6a)
label_encoder = LabelEncoder()
train_data['Target_encoded'] = label_encoder.fit_transform(train_data['Target'])

# Separate features (X) and target (y)
X = train_data.drop(['Target', 'Target_encoded'], axis=1)
y = train_data['Target_encoded']

# Store test_id and drop 'id' from test_data features
test_ids = test_data['id']
X_test = test_data.drop('id', axis=1)

# Ensure both train and test sets have the same columns in the same order
common_cols = list(set(X.columns) & set(X_test.columns))
X = X[common_cols]
X_test = X_test[common_cols]



# 3. Train Hyperparameter Tuning Model (from cell eZ3F_Nv2-CSO)
param_dist = {
    'max_depth': [3, 5, 7, 10, None],  # Maximum depth of the tree
    'min_samples_split': [2, 5, 10],   # Minimum number of samples required to split an internal node
    'min_samples_leaf': [1, 2, 4],     # Minimum number of samples required to be at a leaf node
    'criterion': ['gini', 'entropy']   # Function to measure the quality of a split
}

# Initialize Decision Tree Classifier
dt_classifier = DecisionTreeClassifier(random_state=42)

# Initialize RandomizedSearchCV with 3-fold cross-validation and 20 iterations
random_search = RandomizedSearchCV(estimator=dt_classifier, param_distributions=param_dist,
                                   n_iter=20, cv=StratifiedKFold(n_splits=3, shuffle=True, random_state=42),
                                   scoring='accuracy', n_jobs=-1, verbose=1, random_state=42)

# Fit the RandomizedSearchCV to the training data
random_search.fit(X, y)


# Get the best model
best_dt_model = random_search.best_estimator_

# 4. Predict on Test Data (from cell 28043438)
test_predictions_encoded = best_dt_model.predict(X_test)

# Inverse transform the predictions to get original labels
test_predictions = label_encoder.inverse_transform(test_predictions_encoded)
# Write your final code here as per the instructions
target_mapping = {'Dropout': 0, 'Enrolled': 1, 'Graduate': 2}

submission_df = pd.DataFrame({
    'id': test_ids,
    'Target': [target_mapping[val] for val in test_predictions]
})


# Save to csv
submission_df.to_csv('submission.csv', index=False)
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
